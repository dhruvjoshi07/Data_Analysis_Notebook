# %% [markdown]
# We use distribution plots to visualize the distribution of quantitative data
# Lets discuss some plots that allow us to viualize the  distribution of a data set.These plots are:
# distplot/histplot,
# joinplot,
# pairplot,
# rugplot

# %%
# age is quantativeive and gender is qualative
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
#histogram
sns.displot(df['total_bill'])

# %%
sns.histplot(df['total_bill'],bins=30,kde=True)  #kernal density estimater shows data skewness
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
plt.subplot(1,2,1)
sns.histplot(df['total_bill'],bins=20,kde=True)
plt.subplot(1,2,2)
sns.histplot(df['tip'],bins=20,kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
#jointplot
sns.jointplot(x='total_bill',y='tip',data=df)

# %%
# jointplot
sns.jointplot(x='total_bill',y='tip',data=df,kind="kde")

# %%
# jointplot
sns.jointplot(x='total_bill',y='tip',data=df,kind='hex')

# %%
# jointplot
sns.jointplot(x='total_bill',y='tip',data=df,kind='reg')

# %%
#pairplot
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')   #hue simply her ek cheej btata hai

# %%
sns.pairplot(df,hue='size',palette="rainbow")

# %%
#rugplot
sns.rugplot(df)
# Out:
# <Axes: >

# %%
'''Categorical plot
Box plot
violinplot
stripplot
swarmplot
barplot
countplot'''
# Out:
# 'Categorical plot\nBox plot\nviolinplot\nstripplot\nswarmplot\nbarplot\ncountplot'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#countplot,check kitne hai 
sns.countplot(x=df["sex"])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#now we r divide kitne smoke krte hai kite nhi
sns.countplot(x=df['sex'],hue=df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#barplot takes x and y axis
#y axis mei quantative (continous) jata hau
#x axis mei ca
sns.barplot(x=df['sex'],y=df['total_bill'])
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x=df['sex'],y=df['total_bill'],estimator=np.sum)  #deafult pr mean hota estimator
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
#box plot created by 5 number summary
sns.boxplot(x='tip',y='day',data=df,palette="rainbow")
# Out:
# C:\Users\DHRUV JOSHI\AppData\Local\Temp\ipykernel_6728\882847136.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='tip',y='day',data=df,palette="rainbow")
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
#  ## boxplot and violinplot
#
#
# Boxplot and violinplot are used to shown the distribution of categorical data.a box plot (or box and whisker plot) shows the distribution of quantittative data in a way that facilitates comparisons btw var or across levels of a categorical var.the box shows the quartiles of dataset while the whiskers extend to show the rest of distribution ,except for points that are determined to be "outliers"using a method that is fx of inner quartile range

# %%
sns.violinplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
#  ## stripplot and swarmplot
# The stripplot will draw a scatterplot where one variable is categorical.A strip plot can be drawn on its own,but it is also a good complement to a box or violin plot in cases where u want to show all observations along with some representation of the underlying distributio .
#
# The swarmplot is similar to stripplot(),but the points are adjusted (only along the categorical axis) so that they don't overlap.This gives a better representation of the distribution of values,although it does not scale as well to large numbers of observations(both in terms of the ability to show all the points and in terms of the compuatation needed to arrange them).

# %%
sns.stripplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#violin and swarm sath mei
sns.violinplot(x='tip',y='day',data=df)
sns.swarmplot(x='tip',y='day',data=df)
# Out:
# C:\Users\DHRUV JOSHI\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 9.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DHRUV JOSHI\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='tip', ylabel='day'>
# C:\Users\DHRUV JOSHI\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
'''MATRIX PLOT
Heat map
cluster map
pivot table heat map'''
# Out:
# 'MATRIX PLOT\nHeat map\ncluster map\npivot table heat map'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
flights=sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
tip=sns.load_dataset('tips')
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
#  ## HEAT MAP

# %%
#heatmap mei colreln ana chahiye
tip_score=tip[['total_bill','tip','size']]   #ab corln calculate krenge pr tip data set k sirf numeric wle sb col likh do
tip_score
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
tip_score.corr()    #corr means corelation
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tip_score.corr(),annot=True )
# Out:
# <Axes: >

# %% [markdown]
#  ## CLUSTER MAP

# %%
sns.clustermap(tip_score.corr(),annot=True )

# %% [markdown]
# ## PIVOT TABLE HEAT MAP

# %%
pivot_flight=flights.pivot_table(values='passengers',index='month',columns='year')
pivot_flight
# Out:
# C:\Users\DHRUV JOSHI\AppData\Local\Temp\ipykernel_6728\4288438390.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_flight=flights.pivot_table(values='passengers',index='month',columns='year')
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# ...

# %%
sns.heatmap(pivot_flight)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## Regression Plot

# %% [markdown]
#  ## Lmplot()
#
# regression plot is used in ml so we will not fully discuss what,how and where it is used but we will see how it is created  and what are the values we can put inside it

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips=sns.load_dataset("tips")

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)   #total_bill mei tip predict krna chahta hu

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue="sex")

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue="sex",palette="coolwarm")

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue="sex",palette="rainbow",markers=["o","v"])  #o -oval,v-traingle

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue="sex",palette="rainbow",markers=["o","v"],scatter_kws={'s':100}) #scatter_kws size k liye hota hai
