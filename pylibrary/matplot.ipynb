# %%
'''Data Visulaizagtion'''
#MATLAB is a high level programming language and a numerical computing environment used by engineers and sctists for data analysis,visuaization and alg development
# Out:
# 'Data Visulaizagtion'

# %%
'''
Matplotlib
Distribution plots
categorical plot
matrix plot
regression plots
cufflinks+plotly
'''
# Out:
# '\nMatplotlib\nDistribution plots\ncategorical plot\nmatrix plot\nregression plots\ncufflinks+plotly\n'

# %%
# Matplotlib Topics
'''
Matplotlib basics
object oriented way
types of plots
saving plots
working with images
optional desiging
'''
# Out:
# '\nMatplotlib basics\nobject oriented way\ntypes of plots\nsaving plots\nworking with images\noptional desiging\n'

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_axis=np.linspace(0,5,11)
x_axis
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y_axis=x**2
y_axis
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#plot bnata hai line chart
plt.plot(x_axis,y_axis) 
plt.title("Matplotlib LPlot")
plt.xlabel("X axis")
plt.ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
#subplots in plot
plt.subplot(2,2,1)
plt.plot(x**2,x**2)
plt.subplot(2,2,2)
plt.plot(y,x)
plt.subplot(2,2,3)
plt.plot(y**2,x**2)
plt.subplot(2,2,4)
#for 4 
plt.plot(x,y)
