# %%
'''Data Visulaizagtion'''
#MATLAB is a high level programming language and a numerical computing environment used by engineers and sctists for data analysis,visuaization and alg development
# Out:
# 'Data Visulaizagtion'

# %%
'''
Matplotlib
Distribution plots
categorical plot
matrix plot
regression plots
cufflinks+plotly
'''
# Out:
# '\nMatplotlib\nDistribution plots\ncategorical plot\nmatrix plot\nregression plots\ncufflinks+plotly\n'

# %%
# Matplotlib Topics
'''
Matplotlib basics
object oriented way
types of plots
saving plots
working with images
optional desiging
'''
# Out:
# '\nMatplotlib basics\nobject oriented way\ntypes of plots\nsaving plots\nworking with images\noptional desiging\n'

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_axis=np.linspace(0,5,11)
x_axis
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y_axis=x_axis**2
y_axis
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#plot bnata hai line chart
plt.plot(x_axis,y_axis) 
plt.title("Matplotlib LPlot")
plt.xlabel("X axis")
plt.ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
#subplots in plot
plt.subplot(2,2,1)
plt.plot(x**2,x**2)
plt.subplot(2,2,2)
plt.plot(y,x)
plt.subplot(2,2,3)
plt.plot(y**2,x**2)
plt.subplot(2,2,4)
#for 4 
plt.plot(x,y)

# %%
''''object oriented way'''
# Out:
# "'object oriented way"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Matplotlib allows the aspect ratio,DPI and figure size to be specified when the figure object is created.You can use the figsize and dpi keyword arguments
# figsize is a tupe of the width and height of the figure in inches dpi is the dots-per-inch(pxel per inch)

# %%
fig=plt.figure(figsize=(12,8))   #600*800(width,height)
axis1=fig.add_axes([0.1,0.1,.8,.8])  #left,bottom,width,height(0 to 1)
axis1.plot(x_axis,y_axis)
axis2=fig.add_axes([1,1,0.3,0.3]) 
axis2.plot(x_axis,y_axis)

# %%
'''Types of plot'''

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,6,13)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ])

# %%
y=x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  , 30.25, 36.  ])

# %%
plt.plot(x,y) 
plt.xlabel("X axis")
plt.ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
plt.scatter(x,y)

# %%
plt.hist(x)
# Out:
# (array([2., 1., 1., 1., 1., 2., 1., 1., 1., 2.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
from random import sample
data=sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([15., 10., 11.,  7., 10.,  9., 12.,  6., 14.,  6.]),
#  array([  4. , 103.4, 202.8, 302.2, 401.6, 501. , 600.4, 699.8, 799.2,
#         898.6, 998. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1db9f3ef9d0>,
#   <matplotlib.lines.Line2D at 0x1db9f3efb10>],
#  'caps': [<matplotlib.lines.Line2D at 0x1db9f3efc50>,
#   <matplotlib.lines.Line2D at 0x1db9f3efd90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1db9f3ef890>],
#  'medians': [<matplotlib.lines.Line2D at 0x1db9f3efed0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1db9f624050>],
#  'means': []}

# %%
#saving plots
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig("basicplot.png")

# %%
#working with images
'''only matplotlib can do cuz of numpy but seaborn cannot do'''
import matplotlib.image as mpimg
img=mpimg.imread('luffy.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 4
#       1 #working with images
#       2 '''only matplotlib can do cuz of numpy but seaborn cannot do'''
#       3 import matplotlib.image as mpimg
# ----> 4 img=mpimg.imread('luffy.jpg')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\image.py:1520, in imread(fname, format)
#    1513 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1514     # Pillow doesn't handle URLs directly.
#    1515     raise ValueError(
#    1516         "Please open the URL for reading and pass the "
#    1517         "result to Pillow, e.g. with "
#    1518         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1519         )
# -> 1520 with img_open(fname) as image:
#    1521     return (_pil_png_to_float_array(image)
#    1522             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1523             pil_to_array(image))
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:3493, in open(fp, mode, formats)
#    3491 if is_path(fp):
#    3492     filename = os.fspath(fp)
# -> 3493     fp = builtins.open(filename, "rb")
#    3494     exclusive_fp = True
#    3495 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'luffy.jpg'
