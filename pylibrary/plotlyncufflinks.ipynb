# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# Requirement already satisfied: plotly in c:\users\dhruv joshi\anaconda3\lib\site-packages (6.3.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\dhruv joshi\anaconda3\lib\site-packages (from plotly) (2.7.0)
# Requirement already satisfied: packaging in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from plotly) (26.0)
# Collecting cufflinks
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.9.2 in c:\users\dhruv joshi\anaconda3\lib\site-packages (from cufflinks) (2.3.5)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\dhruv joshi\anaconda3\lib\site-packages (from cufflinks) (2.3.3)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\dhruv joshi\anaconda3\lib\site-packages (from cufflinks) (6.3.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from cufflinks) (1.17.0)
# Collecting colorlover>=0.2.1 (from cufflinks)
#   Downloading colorlover-0.3.0-py3-none-any.whl.metadata (421 bytes)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\dhruv joshi\anaconda3\lib\site-packages (from cufflinks) (80.9.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from cufflinks) (9.12.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\dhruv joshi\anaconda3\lib\site-packages (from cufflinks) (8.1.7)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->cufflinks) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.6.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\dhruv joshi\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\dhruv joshi\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.15)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from jedi>=0.18.2->ipython>=5.3.0->cufflinks) (0.8.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dhruv joshi\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dhruv joshi\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\dhruv joshi\anaconda3\lib\site-packages (from plotly>=4.1.1->cufflinks) (2.7.0)
# Requirement already satisfied: packaging in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from plotly>=4.1.1->cufflinks) (26.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\dhruv joshi\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (0.2.3)
# Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Building wheels for collected packages: cufflinks
#   Building wheel for cufflinks (pyproject.toml): started
#   Building wheel for cufflinks (pyproject.toml): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68559 sha256=924fd7a1927e08afdd4cc9a9e2abbc5c925dbb398b6cecd40b7f8d9968c1b216
#   Stored in directory: c:\users\dhruv joshi\appdata\local\pip\cache\wheels\13\bc\65\1ac45445dba1052b5e837dc49f5282c8cb2f934ae9e6f62f0e
# Successfully built cufflinks
# Installing collected packages: colorlover, cufflinks
#
#    -------------------- ------------------- 1/2 [cufflinks]
#    -------------------- ------------------- 1/2 [cufflinks]
#    ---------------------------------------- 2/2 [cufflinks]
#
# Successfully installed colorlover-0.3.0 cufflinks-0.17.3

# %%
import seaborn as sns
import pandas as pd
import cufflinks as cf
from plotly.offline import iplot

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
pd.options.plotting.backend = "plotly"

# %%
tips['total_bill'].plot()

# %%
#bar chart k liye group by krdo
tips.groupby('day')['tip'].mean().plot(kind='bar')
# Out:
# C:\Users\DHRUV JOSHI\AppData\Local\Temp\ipykernel_1552\2487743647.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
#scatter plot
tips.plot(kind='scatter',x='total_bill',y='tip')

# %%
tips[['total_bill','day']].plot(kind='box',x='total_bill',y='day')
