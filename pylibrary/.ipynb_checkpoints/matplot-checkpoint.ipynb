# %%
'''Data Visulaizagtion'''
#MATLAB is a high level programming language and a numerical computing environment used by engineers and sctists for data analysis,visuaization and alg development
# Out:
# 'Data Visulaizagtion'

# %%
'''
Matplotlib
Distribution plots
categorical plot
matrix plot
regression plots
cufflinks+plotly
'''
# Out:
# '\nMatplotlib\nDistribution plots\ncategorical plot\nmatrix plot\nregression plots\ncufflinks+plotly\n'

# %%
# Matplotlib Topics
'''
Matplotlib basics
object oriented way
types of plots
saving plots
working with images
optional desiging
'''
# Out:
# '\nMatplotlib basics\nobject oriented way\ntypes of plots\nsaving plots\nworking with images\noptional desiging\n'

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_axis=np.linspace(0,5,11)
x_axis
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y_axis=x_axis**2
y_axis
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#plot bnata hai line chart
plt.plot(x_axis,y_axis) 
plt.title("Matplotlib LPlot")
plt.xlabel("X axis")
plt.ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
#subplots in plot
plt.subplot(2,2,1)
plt.plot(x**2,x**2)
plt.subplot(2,2,2)
plt.plot(y,x)
plt.subplot(2,2,3)
plt.plot(y**2,x**2)
plt.subplot(2,2,4)
#for 4 
plt.plot(x,y)

# %%
''''object oriented way'''
# Out:
# "'object oriented way"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Matplotlib allows the aspect ratio,DPI and figure size to be specified when the figure object is created.You can use the figsize and dpi keyword arguments
# figsize is a tupe of the width and height of the figure in inches dpi is the dots-per-inch(pxel per inch)

# %%
fig=plt.figure(figsize=(12,8))   #600*800(width,height)
axis1=fig.add_axes([0.1,0.1,.8,.8])  #left,bottom,width,height(0 to 1)
axis1.plot(x_axis,y_axis)
axis2=fig.add_axes([1,1,0.3,0.3]) 
axis2.plot(x_axis,y_axis)

# %%
'''Types of plot'''

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,6,13)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ])

# %%
y=x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  , 30.25, 36.  ])

# %%
plt.plot(x,y) 
plt.xlabel("X axis")
plt.ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
plt.scatter(x,y)

# %%
plt.hist(x)
# Out:
# (array([2., 1., 1., 1., 1., 2., 1., 1., 1., 2.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
from random import sample
data=sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([15., 10., 11.,  7., 10.,  9., 12.,  6., 14.,  6.]),
#  array([  4. , 103.4, 202.8, 302.2, 401.6, 501. , 600.4, 699.8, 799.2,
#         898.6, 998. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1db9f3ef9d0>,
#   <matplotlib.lines.Line2D at 0x1db9f3efb10>],
#  'caps': [<matplotlib.lines.Line2D at 0x1db9f3efc50>,
#   <matplotlib.lines.Line2D at 0x1db9f3efd90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1db9f3ef890>],
#  'medians': [<matplotlib.lines.Line2D at 0x1db9f3efed0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1db9f624050>],
#  'means': []}

# %%
#saving plots
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig("basicplot.png")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
#working with images
'''only matplotlib can do cuz of numpy but seaborn cannot do'''
img=mpimg.imread('luffy.jpg')

plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(735.5), np.float64(415.5), np.float64(-0.5))

# %%
cropped_img=img[50:200,100:300]
plt.imshow(cropped_img)

# %%
#Desigining
plt.plot(x,y,color="pink")

# %%
xaxis=np.linspace(0,5.11)
xaxis
# Out:
# array([0.        , 0.10428571, 0.20857143, 0.31285714, 0.41714286,
#        0.52142857, 0.62571429, 0.73      , 0.83428571, 0.93857143,
#        1.04285714, 1.14714286, 1.25142857, 1.35571429, 1.46      ,
#        1.56428571, 1.66857143, 1.77285714, 1.87714286, 1.98142857,
#        2.08571429, 2.19      , 2.29428571, 2.39857143, 2.50285714,
#        2.60714286, 2.71142857, 2.81571429, 2.92      , 3.02428571,
#        3.12857143, 3.23285714, 3.33714286, 3.44142857, 3.54571429,
#        3.65      , 3.75428571, 3.85857143, 3.96285714, 4.06714286,
#        4.17142857, 4.27571429, 4.38      , 4.48428571, 4.58857143,
#        4.69285714, 4.79714286, 4.90142857, 5.00571429, 5.11      ])

# %%
fig,ax=plt.subplots(figsize=(12,6))

ax.plot(xaxis,xaxis+1,color="red",linewidth=0.25)
ax.plot(xaxis,xaxis+2,color="red",linewidth=0.50)
ax.plot(xaxis,xaxis+3,color="red",linewidth=1.00)
ax.plot(xaxis,xaxis+4,color="red",linewidth=2.00)

#possible linestyle options '-',':','steps'
ax.plot(xaxis,xaxis+5,color="green",lw=3,linestyle='-')
ax.plot(xaxis,xaxis+6,color="green",lw=3,ls='-.')
ax.plot(xaxis,xaxis+7,color="green",lw=3,ls=':')

#custom dash
line, = ax.plot(xaxis,xaxis+8,color="black",lw=1.50)
line.set_dashes([5,50,15,50])    #format:line length,space length...

#possible marker symbols:marker='+','o','*','s','.','1','2'...
ax.plot(xaxis,xaxis+9,color="blue",lw=3,ls='-',marker='+')
ax.plot(xaxis,xaxis+10,color="blue",lw=3,ls='--',marker='o')
ax.plot(xaxis,xaxis+11,color="blue",lw=3,ls='-',marker='s')
ax.plot(xaxis,xaxis+12,color="blue",lw=3,ls='--',marker='1')
ax.plot(xaxis,xaxis+13,color="purple",lw=1,ls='-',marker='o',markersize=2)
ax.plot(xaxis,xaxis+14,color="purple",lw=1,ls='-',marker='o',markersize=4)
ax.plot(xaxis,xaxis+15,color="purple",lw=1,ls='-',marker='o',markersize=8,markerfacecolor="red")
ax.plot(xaxis,xaxis+16,color="purple",lw=1,ls='-',marker='s',markersize=8,markerfacecolor="yellow",
        markeredgewidth=3,markeredgecolor="green");
